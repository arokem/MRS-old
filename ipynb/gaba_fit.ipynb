# %%
import MRS.quantify as quant

# %%
f_ppm, e1, e2 = quant.reconstruct('/Users/arokem/projects/MRS/MRS/data/P58368.7')

# %%
F1 = quant.Fitter(e1, f_ppm)

# %%
design_matrix = F1.design_matrix()

# %%
fig, ax1 = plt.subplots(1)
ax1.plot(f_ppm, e1.T)
ax1.invert_xaxis()

fig, ax2 = plt.subplots(1)
ax2.plot(f_ppm, e2.T)
ax2.invert_xaxis()
